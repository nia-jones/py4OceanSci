# %% [markdown]
# # Data Visualisation
#
# <img src="images/viz_cartoon.jpeg" width=600 align="center">
#
# Today we'll be using the matplotlib, seaborn, and bokeh packages today to visualise some static plots, videos and create interactive plots. As always, lets first load in the packages we'll be using:

# %%
# data visualisation packages 
import matplotlib.pyplot as plt 
import seaborn as sns
import bokeh  

# other packages 
import numpy as np

# %% [markdown]
# ## Basic Plots with matplotlib and seaborn

# %% [markdown]
# The most popular Python package for visualisations is ```matplotlib``` and its module ```matplotlib.pyplot```. It is based on the MATLAB plotting system, so if you're used to MATLAB you'll find some of the commands familiar. Another common package is ```seaborn```, which is largely based on R's ggplot, and so R users might find this more familiar. You can use both packages in conjunction with each other to get your desired visualisations. See the matplotlb and seaborn galleries (below) to get an idea of what is possible once you get used to the syntax.
#
# **Matplotlib gallery:** https://matplotlib.org/stable/gallery/index.html
#
# **Seaborn gallery:** https://seaborn.pydata.org/examples/index.html

# %%
# let's create some random values to plot
x = np.random.randn(100) 
y = np.random.randn(100)

# %% [markdown]
# Let's create a simple plot just using ```matplotlib.pyplot```:

# %%
fig = plt.figure()  # create a new figure (or activate an existing figure)
plt.scatter(x,y,label='Data') # plot the data in a scatter plot 

# set y and x labels 
plt.ylabel('Y Label') 
plt.xlabel('X Label')

# insert legend 
plt.legend()

# show the plot 
plt.show()

# %% [markdown]
# We can create a very similar plot using the ```sns.scatterplot``` function:

# %%
fig = plt.figure() 
sns.scatterplot(x=x,y=y,label='Data')
plt.legend()

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# In seaborn plots you can specify the 'hue' argument to group the points by colour according to a specific variable:

# %%
fig = plt.figure() 
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# You can also specify the 'style' argument to group the points into different marker styles according to a specific variable:

# %%
fig = plt.figure() 
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="time",style='time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Using some basic ```matplotlib``` commands we can override the labels which seaborn gives the axes:

# %%
fig = plt.figure() 
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="day",style='time')
plt.xlabel('Total Bill (£)')
plt.ylabel('Tip (£)')
# Out:
# Text(0, 0.5, 'Tip (£)')

# %% [markdown]
# ## Plot Aesthetics and Accessibility
#
# Now we understand the basic building blocks of a plot using ```matplotlib``` and ```seaborn``` we can begin to fine tune how we want the plot to look.
#
# Let's first look at colour. There are thousands of colourmaps out there for you to use for your plots.
#
# Matplotlib has its own range of colourmaps:

# %%
from pylab import *
from numpy import outer
rc('text', usetex=False)
a=outer(arange(0,1,0.01),ones(10))
figure(figsize=(10,5))
subplots_adjust(top=0.8,bottom=0.05,left=0.01,right=0.99)
maps=[m for m in cm.datad if not m.endswith("_r")]
maps.sort()
l=len(maps)+1
for i, m in enumerate(maps):
    subplot(1,l,i+1)
    axis("off")
    imshow(a,aspect='auto',cmap=get_cmap(m),origin="lower")
    title(m,rotation=90,fontsize=10)

# %% [markdown]
# Seaborn has its own set of colormaps as well as borrowing from the 'ColorBrewer' palettes (same as R). Let's print one of them as an example:

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.color_palette('colorblind')
# Out:
# [(0.00392156862745098, 0.45098039215686275, 0.6980392156862745),
#  (0.8705882352941177, 0.5607843137254902, 0.0196078431372549),
#  (0.00784313725490196, 0.6196078431372549, 0.45098039215686275),
#  (0.8352941176470589, 0.3686274509803922, 0.0),
#  (0.8, 0.47058823529411764, 0.7372549019607844),
#  (0.792156862745098, 0.5686274509803921, 0.3803921568627451),
#  (0.984313725490196, 0.6862745098039216, 0.8941176470588236),
#  (0.5803921568627451, 0.5803921568627451, 0.5803921568627451),
#  (0.9254901960784314, 0.8823529411764706, 0.2),
#  (0.33725490196078434, 0.7058823529411765, 0.9137254901960784)]

# %%
sns.color_palette('dark')
# Out:
# [(0.0, 0.10980392156862745, 0.4980392156862745),
#  (0.6941176470588235, 0.25098039215686274, 0.050980392156862744),
#  (0.07058823529411765, 0.44313725490196076, 0.10980392156862745),
#  (0.5490196078431373, 0.03137254901960784, 0.0),
#  (0.34901960784313724, 0.11764705882352941, 0.44313725490196076),
#  (0.34901960784313724, 0.1843137254901961, 0.050980392156862744),
#  (0.6352941176470588, 0.20784313725490197, 0.5098039215686274),
#  (0.23529411764705882, 0.23529411764705882, 0.23529411764705882),
#  (0.7215686274509804, 0.5215686274509804, 0.0392156862745098),
#  (0.0, 0.38823529411764707, 0.4549019607843137)]

# %% [markdown]
# As well as using the in-built package colormaps you can also load external colormaps.
#
# One I reccommend is ```cmocean``` which is a collection of commonly-used oceanographic variables which are perceptually uniform and colorblind friendly. Load them in to see what they look like below:

# %%
import cmocean
cmocean.cm.cmapnames
# Out:
# ['thermal',
#  'haline',
#  'solar',
#  'ice',
#  'gray',
#  'oxy',
#  'deep',
#  'dense',
#  'algae',
#  'matter',
#  'turbid',
#  'speed',
#  'amp',
#  'tempo',
#  'rain',
#  'phase',
#  'topo',
#  'balance',
#  'delta',
#  'curl',
#  'diff',
#  'tarn']

# %%
cmocean.cm.thermal

# %%
cmocean.cm.haline

# %% [markdown]
# You can set the style of your plot using seaborn to change the aesthetics of your plot quickly.

# %%
sns.set_style('darkgrid')

fig = plt.figure() 
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="day",style='time',palette='colorblind')
plt.xlabel('Total Bill (£)')
plt.ylabel('Tip (£)')
plt.legend(bbox_to_anchor=[1,0.7],edgecolor='none',facecolor='none')

# %% [markdown]
# ## Maps using Basemap

# %% [markdown]
# Similarly to MATLAB's m_map, Python has 'Basemap' which can allow you to plot maps quickly.

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# setup Lambert Conformal basemap.
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution='c',lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)
# draw coastlines.
m.drawcoastlines()

# draw a boundary around the map, fill the background.
# this background will end up being the ocean color, since
# the continents will be drawn on top.
m.drawmapboundary(fill_color='aqua')

# fill continents, set lake color same as ocean color.
m.fillcontinents(color='coral',lake_color='aqua')

plt.show()

# %% [markdown]
# ## Interactive Plots using Bokeh
#
# Interactive plots can be a great way to engage with stakeholders, students and collaborators. Bokeh uses a fairly simple syntax to create professional looking plots in html.
# https://docs.bokeh.org/en/latest/docs/gallery.html

# %%
import numpy as np

from bokeh.plotting import figure, show

N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = np.array([ [r, g, 150] for r, g in zip(50 + 2*x, 30 + 2*y) ], dtype="uint8")

TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,help"

p = figure(tools=TOOLS)

p.scatter(x, y, radius=radii,
          fill_color=colors, fill_alpha=0.6,
          line_color=None)

show(p)

# %%
import pandas as pd
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show
from bokeh.sampledata.periodic_table import elements

elements = elements.copy()
elements = elements[elements["atomic number"] <= 82]
elements = elements[~pd.isnull(elements["melting point"])]
mass = [float(x.strip("[]")) for x in elements["atomic mass"]]
elements["atomic mass"] = mass

palette = ["#053061", "#2166ac", "#4393c3", "#92c5de", "#d1e5f0",
           "#f7f7f7", "#fddbc7", "#f4a582", "#d6604d", "#b2182b", "#67001f"]

melting_points = elements["melting point"]
low = min(melting_points)
high = max(melting_points)
melting_point_inds = [int(10*(x-low)/(high-low)) for x in melting_points] #gives items in colors a value from 0-10
elements['melting_colors'] = [palette[i] for i in melting_point_inds]

TITLE = "Density vs Atomic Weight of Elements (colored by melting point)"
TOOLS = "hover,pan,wheel_zoom,box_zoom,reset,save"

p = figure(tools=TOOLS, toolbar_location="above", width=1200, title=TITLE)
p.toolbar.logo = "grey"
p.background_fill_color = "#efefef"
p.xaxis.axis_label = "atomic weight (amu)"
p.yaxis.axis_label = "density (g/cm^3)"
p.grid.grid_line_color = "white"
p.hover.tooltips = [
    ("name", "@name"),
    ("symbol:", "@symbol"),
    ("density", "@density"),
    ("atomic weight", "@{atomic mass}"),
    ("melting point", "@{melting point}")
]

source = ColumnDataSource(elements)

p.scatter("atomic mass", "density", size=12, source=source,
          color='melting_colors', line_color="black", alpha=0.9)

labels = LabelSet(x="atomic mass", y="density", text="symbol", y_offset=8,
                  text_font_size="11px", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)

# %% [markdown]
# ## Animations
#
# You may need to create an animation to see how a plots change over time. You can do this within matplotlib like below:

# %%
seaice = sns.load_dataset('seaice') # load in one of the seaborn test data sets. 
seaice.head(-5)
# Out:
#             Date  Extent
# 0     1980-01-01  14.200
# 1     1980-01-03  14.302
# 2     1980-01-05  14.414
# 3     1980-01-07  14.518
# 4     1980-01-09  14.594
# ...          ...     ...
# 13165 2019-12-22  12.327
# 13166 2019-12-23  12.436
# 13167 2019-12-24  12.494
# 13168 2019-12-25  12.545
# 13169 2019-12-26  12.638
#
# [13170 rows x 2 columns]

# %%
plt.figure()
sns.lineplot(data=seaice,x='Date',y='Extent')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Extent'>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
Writer = animation.writers['ffmpeg']
writer = Writer(fps=20, bitrate=1800)

# %%
fig = plt.figure(figsize=(10,6))
plt.xlim(0, 1000)
plt.ylim(0, 17)

def animate(i):
    data = seaice.iloc[:int(i+1)] #select data range
    p = sns.lineplot(x=data.index, y=data['Extent'], data=data, color="r")
    p.tick_params(labelsize=17)
    plt.setp(p.lines,linewidth=7)
    
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=1000, repeat=True)
ani.save('video.mp4', writer=writer)
